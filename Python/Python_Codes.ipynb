# %% [markdown]
# # Pyton Practice

# %%
A = [1]
B = ["a"]
C = [4.2]
print(A+B+C)

a = 'He'
b = 'llo'
c = ',World'
print(a+b+c)

a1 = 999
print(a1)

_a = 999
print(_a)

print(type(a))
print(type(b))

# %%
a = 1
print(a)

del a

input_num = input("숫자를 입력해주세요 : ")
print(input_num)
print(type(input_num))

total_str = input_num * 5
print(total_str)

total_int = int(input_num)*5
print(total_int)

print(1111, "안녕하세요", 345, sep = "\n")

# %%
a = 1 ; b = 2
print(a, b)

a, b = b, a
print(a, b)

a = 1
print(a)

a += 10
print(a)

a -= 5
print(a)

import keyword
print(keyword.kwlist)

a = '1234'
print(len(a))

a = [1, 2, 3, 4, 5]
print(len(a))

print(max(1, 2, 3, 4, 5))

# %%
# Mission 1 / 한 줄에 여러 변수 값 할당
print("안녕하세요");print("학습자님")
print("이번 회차도 수고하셨습니다.")

print("안녕하세요","학습자님", "이번 회차도 수고하셨습니다.", sep='\n')

# Mission 2 / 입력하고 출력하기
a = input("첫 번째 숫자를 입력해주세요 : ")
b = input("두 번째 숫자를 입력해주세요 : ")
print(int(a) + int(b))

# %%
a = 1
print(a)

b = 1
print(b)

print(id(a))
print(id(b))

a = 0
print(type(a))

a = 12345
print(type(a))

b = 0b11
print(type(b))

a = ""

# %%
a = float("0.12")
print(type(a))
print(a)

print(a * 5)

b = 2e-4
print(type(b))
print(b)

c = 3e3

b = "Hello, World!"
print(type(b))
print(b)

a = "안녕하세요"
print(a)

a = "\'안녕하세요'"
print(a)

a = "Hello \nWorld \nPython"

# %%
a = 5 % 3
print(a)

print(divmod(5, 3))

print(5 ** 3)

print(pow(5, 3))

a = 5
a += 3
print(a)

a ** 3
print(a)

import math
# 상용로그
print(math.log10(10))

# 제곱근
print(math.sqrt(8))

# %%
a = "안녕하세요"
print(a[1 : 3])

# %%
# 반지름 입력
r = input("> 반지름을 입력하세요. : ")

# 출력
print("반지름 : ", r)
print("둘레 : ", 2 * 3.14 * float(r))
print("넓이 : ", 3.14 * float(r) ** 2)

# %%
# 값을 입력 받습니다.
number = int(input("> 값을 입력하세요 : "))

# 비교연산자를 이용해서 값 비교하기
if number < 20 :
    result = True
else:
    result = False

# 변수값 출력
print("변수값 출력 : ", result)

# 변수값을 부정으로 처리하여 출력
print("변수값을 부정으로 처리하여 출력 : ", not(result))

# %%
# 튜플_Tuple
t = (1, 2, 3)
print(type(t))
print(t)

# 딕셔너리_dictionary
d = {
        'a' : 1,
        'b' : 2, 
        'c' : 3
        }
print(type(d))
print(d)

print(d.keys())
print(d.values())
print(d.items())

# 집합_Set
s = {1, 2, 3, 4} 
print(s, type(s))

s1 = set([1, 2, 3, 4, 5])
s2 = set([6, 7, 8, 9, 10])
print(s1)
print(s2)

print(s1 & s2) # 교집합
print(s1 | s2) # 합집합
print(s1.union(s2))

print(s1 - s2) # 차집
print(s1.difference(s2))

# %%
# Mission 1
L = [1, 1, 1, 1, 2, 2, 2, 3, 3, 4, 5, 6, 4, 4, 5, 7, 7, 8, 9, 7, 7, 7, 5, 6, 7]

temp = set(L)
L = list(temp)
print(L)

print(L)

# Mission 2
T = (1, 2, 3, 4, 5, 6, 7, 8)

L = list(T)
L[0] = 0
L.remove(8)
L.append(9)

print(L)

# %%
# 리스트 안의 리스트
l = [[1, 2, 3], [4, 5, 6,], [7, 8, 9]]
print(l)

print(l[0])
print(l[0][1])

l = [9, 7, 4, 7, 2, 6, 8, 9]
print(l)

l.insert(0, 1)
print(l)

l.insert(4, '안녕하세요')
print(l)

list_1 = []

for i in range(5):
    list_1.append(i)
print(list_1)

# %%
t = 1, 2, 3
print(type(t))
print(t)

def test():
    # 파이썬의 함수
    return(1, 2)

a, b = test()
print(a)
print(b)

dict1 = {'a' : 1, 'b' : 2, 'c' : 3}
dict2 = {'c' : 4, 'd' : 5, 'e' : 6}

dict.update(dict2)
print(dict1)

# %%
d = {'a' : 1, 'b' : 2, 'c' : 3}

for i in d:
    print(i)
print()

for i in d.values():
    print(i)
print()

for i in d.items():
    print(i)
    
# value 값을 변수에 대입
# if 조건문을 사용하여 값 출력하기

true = 3 in d.values()
print(true)

# %%
import collections
obj = [1, 2, 3, 4]
isinstance(obj, collections.Iterable)

l = ['a', 9, [1, 2, 3], ('a', 'b')]
for i in l:
    print(i)
    
for i in range(len(l)):
    print(l[i])
    
for i in [1, 2, 3, 4]:
    for j in (1, 2, 3, 4):
        print(j, end = ", ")
    print(i, end = ", ")

# %%
# 구구단 작성
for i in range(1, 10, 1):
    for j in range(1, 10, 1):
        print(i * j, end = ", ")

# 답안
for i in range(1, 10,  1):
    for j in range(1, 10, 1):
        print(i, "X", j, "=", i * j, end = "\n")
        print()
        
l = [[1, 2], [3, 4], [5, 6]]
for i , j in l:
    print(i + j)

# %%
# 학생 리스트를 선언합니다.
students = [
    {"name" : "김현우", "korean" : 87, "math" : 98, "english" : 88, "science" : 95},
    {"name" : "연하진", "korean" : 92, "math" : 98, "english" : 96, "science" : 98},
    {"name" : "구자연", "korean" : 76, "math" : 96, "english" : 94, "science" : 90},
    {"name" : "나선주", "korean" : 98, "math" : 92, "english" : 96, "science" : 92},
    {"name" : "윤애린", "korean" : 95, "math" : 98, "english" : 98, "science" : 98},
    {"name" : "윤명월", "korean" : 64, "math" : 88, "english" : 92, "science" : 92},
    {"name" : "김미화", "korean" : 82, "math" : 86, "english" : 98, "science" : 88},
    {"name" : "김연화", "korean" : 88, "math" : 74, "english" : 78, "science" : 92},
    {"name" : "박아현", "korean" : 97, "math" : 92, "english" : 88, "science" : 95},
    {"name" : "서준서", "korean" : 45, "math" : 52, "english" : 72, "science" : 78},
]

# 출력합니다.
print("================")
print(" 성 적 평 균 현 황 ")
print("================")
print("이 름  총 점  평 균")

for student in students:
    print(student["name"], (student["korean"] + student["math"] + student["english"] + student["science"]), (student["korean"] + student["math"] + student["english"] + student["science"]) / 4)

# %%
s = "Hello"
cnt = 0
for i in s:
    if i == "e":
        print("i is ie")
    cnt += 1
print(cnt)

num = 10
while num > 0:
    if num == 6:
        print("--end--")
        break
    print(num)
    num -= 1
    
l = []
for i in range(5):
    if i % 2 == 0:
        l.append(i)
print(l)

# %%
# Mission 1 / 반복문 활용
num = input("출력할 단수를 입력해주세요.")
for i in range(1, 10):
    print("{} X {} = {}".format(num, i, int(num) * i))

# Mission 2 / 리스트 내포 활용
l = []
for i in range(2, 10):
    for j in range(1, 10):
        if i != 4:
            l.append(i * j)
print(l)

print(i * j for i in range(2, 10) for j in range(1, 10) if i != 4)

# %%
# 역순 정렬
a = "안녕하세요"
print(a[::-1])

# 슬라이싱, 연결
b = "12345"
c = "34567"
d = b[0:3] + c[1:]
print(d)

e = "{}{}{}".format("Hello", ", ", "World!")
print(e)

A = "{}".format(1/3)
B = "{:0.2}".format(1/3)

# %%
import os
print(os.getcwd())

f = open("a.text", "w")
f.write("1234")
f.close()

# %%
import sys
f = open('a.txt', 'w')
sys.stdout = f
print("1234")
f.close()

# %%
# 모듈을 읽어 들입니다.
import os

# 기본 정보를 몇 개 출력해 봅시다.
print("현재 운영체제", os.name)

# %%
import sys

f = open("a.txt", 'w')

sys.stdout = f

for i in range(2, 10):
    for j in range(1, 10):
        print("{} X {} = {}".format(i, j, i * j))
    print()
f.close()

# %%
import os

user = os.getlogin() # 사용자 이름(학습자님 사용자 이름을 적어주세요)

# %%
import sys

f = open("a.txt", 'w')
sys.stdout = f

for i in range(2, 10):
    for j in range(1, 10):
        print("{} X {} = {}".format(i, j, i * j))
    print()
f.close()

# %%
import sys

f = open("a.txt", 'w')
sys.stdout = f

for i in range(2, 10):
    for j in range(1, 10):
        print("{} X {} = {}".format(i, j, i * j))
    print()
f.close()

# %%
def fun(a, b):
    return a, b

x = fun(1, 2)
print(x)
print(type(x))

def add(a, b):
    print(a, b)
    
def add2(a, b):
    return a, b

y = add(1, 2)
print(y)

z = add2(1, 2)
print(z)

# %%
# 지역 변수
def func():
    a = 10
    print(a)
    
a = 20
func()
print(a)

# 전역 변수
a = 10
def func():
    print(a)
    
import sys

# %%
# 매개변수 활용
def calculator(a, b, c = 0):
    if int(c) == 0:
        print(int(a) + int(b))
    elif int(c) == 1:
        print(int(a) - int(b))
    elif int(c) == 2:
        print(int(a) * int(b))
    else:
        print(int(a) / int(b))

a = input("> 정수를 입력하세요. : ")
b = input("> 정수를 입력하세요. : ")
c = input("> 연산을 입력하세요 (0 : 덧셈, 1 : 뺄셈, 2 : 곱셈, 3 : 나눗셈) : ")

calculator(a, b)

# %%
def gugu(a):
    for i in range(1, 10):
        print("{} X {} = {}".format(a, i, a * i))

gugu(4)

# %%
print((lambda a, b = 1 : a + b)(3))®

# %%
import sys

f = open("a.txt", 'w')
sys.stdout = f

for i in range(2, 10):
    for j in range(2, 10):
        print("{} X {} = {}".format(i, j, i * j))
    print()

f.close()

# %%
# 학생 리스트를 선언합니다.
students = [
    {"name" : "김현우", "korean" : 87, "math" : 98, "english" : 88, "science" : 95},
    {"name" : "연하진", "korean" : 92, "math" : 98, "english" : 96, "science" : 98},
    {"name" : "구자연", "korean" : 76, "math" : 96, "english" : 94, "science" : 90},
    {"name" : "나선주", "korean" : 98, "math" : 92, "english" : 96, "science" : 92},
    {"name" : "윤애린", "korean" : 95, "math" : 98, "english" : 98, "science" : 98},
    {"name" : "윤명월", "korean" : 64, "math" : 88, "english" : 92, "science" : 92},
    {"name" : "김미화", "korean" : 82, "math" : 86, "english" : 98, "science" : 88},
    {"name" : "김연화", "korean" : 88, "math" : 74, "english" : 78, "science" : 92},
    {"name" : "박아현", "korean" : 97, "math" : 92, "english" : 88, "science" : 95},
    {"name" : "서준서", "korean" : 45, "math" : 52, "english" : 72, "science" : 78},
]

def score_make_total(stduent):
    total = student

# %%
# 학생 리스트를 선언합니다.
students = [
    {"name" : "김현우", "korean" : 87, "math" : 98, "english" : 88, "science" : 95},
    {"name" : "연하진", "korean" : 92, "math" : 98, "english" : 96, "science" : 98},
    {"name" : "구자연", "korean" : 76, "math" : 96, "english" : 94, "science" : 90},
    {"name" : "나선주", "korean" : 98, "math" : 92, "english" : 96, "science" : 92},
    {"name" : "윤애린", "korean" : 95, "math" : 98, "english" : 98, "science" : 98},
    {"name" : "윤명월", "korean" : 64, "math" : 88, "english" : 92, "science" : 92},
    {"name" : "김미화", "korean" : 82, "math" : 86, "english" : 98, "science" : 88},
    {"name" : "김연화", "korean" : 88, "math" : 74, "english" : 78, "science" : 92},
    {"name" : "박아현", "korean" : 97, "math" : 92, "english" : 88, "science" : 95},
    {"name" : "서준서", "korean" : 45, "math" : 52, "english" : 72, "science" : 78},
]

def create_student(name, korean, math, english, science):
    return{
        "name" : name,
        "korean" : korean,
        "math" : math,
        "english" : english,
        "science" : science
    }

bb = create_student("aaa", 90, 80, 70, 60)
print(bb)

# 학생을 한 명씩 반복합니다.
print("이름", "총점", "평균", sep="\t")

# %%
def func(x):
    return x * x

a = [1, 2, 3, 4, 5]
b = map(func, a)
print(type(b))
print(list(b))

# %%
def factorial(n):
    if n == 0:
        return 1
    return n * factorial(n - 1)

print(factorial(15))

fact = lambda x : x == 0 and 1 or x * fact(x - 1)
print(fact(5))

# %%
import urllib.request
web_page = urllib.request.urlopen("https://www.naver.com")
print(web_page.read())

# %%
import urllib.request
import bs4
web_page = urllib.request.urlopen("https://www.naver.com")
result = bs4.BeautifulSoup(web_page, "html.parser")
rank = result.find("ul", class_="ah_l")

for i in rank.find_all("li"):
    print(i.get_text("위 : ", strip = True))

# %%
class Simple_Class:
    pass

c1 = Simple_Class()
c2 = Simple_Class()

c1.a = 10
print(c1.a)
print(c2.a)

class MyClass:
    def class_set(self, v):
        self.value = v

    def class_get(self):
        return self.value

# %%
c = MyClass()
c.class_set('10')
print(c.class_get())

c = MyClass() # 인스턴스 생성
MyClass.class_set(c, '10')
print(MyClass.class_get(c))

# %%
class MyClass:
    def __init__(self):
        self.name = "Class"
        print("클래스가 생성되었습니다.", self.name)
c = MyClass

# %%
# Mission / time 모듈, 클래스의 생성자와 소멸자를 활용하여 객체의 생성, 소멸 시간 출력

from time import ctime, sleep

class Life:
    def __init__(self):
        self.birth = ctime()
        print('Birthday', self.birth)

    def __del__(self):
        print('Deathday', ctime())

def test():
    mylife = Life()
    print("Sleeping for 3 sec")
    sleep(3)

# %%
# 직접 코딩하기

import time

a = 10 # a에 10을 할당
b = 0
cnt = 0 # 시도한 횟수는 초기값 0

print("숫자 맞추기 게임을 시작하겠습니다.")

while a != b:
    b = int(input("> 숫자를 입력하세요. : "))
    if a < b:
        print("숫자를 낮추세요.")
        time.sleep(2)
    if a > b:
        print("숫자를 올리세요.")
        time.sleep(2)
    cnt += 1

print(cnt, "번만에 숫자를 맞추셨습니다.")

# %%
import turtle as myturtle
tt = myturtle.Turtle()
tt.shape('turtle')
tt.shapesize(5, 5, 5)
tt.fillcolor('green')
tt.setheading(90)

tt.forward(500)
tt.backward(500)
tt.left(500)
tt.right(500)

# Turtle Graphics 창 유지
myturtle.mainloop()

# %%
# 총정리 문제
# 1. 일반 코드 작성, 함수화, 클래스화 시키기
# 2. 작업한 결과를 파일로 저장 : result.txt
# 3. 작업 주제 : 코로나19에 관한 통계 작업
#     데이터 : NAVER_코로나19 지역별 현황

print("코로나19 통계")
print("===================================")
print("지역", "확진 누계", "신규 확진", "총 계", "예상 비용", sep="\t")
print("===================================")

import urllib.request
web_page = urllib.request.urlopen("https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EC%BD%94%EB%A1%9C%EB%82%9819")
print(web_page.read)

import bs4
result = bs4.BeautifulSoup(web_page, "html.parser")
print(result)

found_result = result.find(class_="local_link")
region_list = found_result.find_all(self)

for n in range(0, len(region_list)):
    region_name = region_list[n].find(class_="local_link")

import sys
sys.stdout = open("권경호.txt")

class COVID:
    def __init__(self, region, past, new):

# %%
from urllib import request
from bs4 import BeautifulSoup

target = request.urlopen("https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EC%BD%94%EB%A1%9C%EB%82%9819")

soup = BeautifulSoup(target, "html.parser")

# location 태그를 찾습니다.
for location in soup.select("location"):
    print("f")

# %%
# 학생 리스트를을 선언합니다.
students = [
    { "name": "김지욘", "korean": 87, "math": 98, "english": 88, "science": 95 },
    { "name": "연하진", "korean": 92, "math": 98, "english": 96, "science": 98 },
    { "name": "구지연", "korean": 76, "math": 96, "english": 94, "science": 90 },
    { "name": "나선주", "korean": 98, "math": 92, "english": 96, "science": 92 },
    { "name": "윤아린", "korean": 95, "math": 98, "english": 98, "science": 98 },
    { "name": "윤명월", "korean": 64, "math": 88, "english": 92, "science": 92 },
    { "name": "김미화", "korean": 82, "math": 86, "english": 98, "science": 88 },
    { "name": "김연화", "korean": 88, "math": 74, "english": 78, "science": 92 },
    { "name": "박아현", "korean": 97, "math": 92, "english": 88, "science": 95 },
    { "name": "서준서", "korean": 45, "math": 52, "english": 72, "science": 78 }
]

# 학생을 한 명씩 반복합니다.
print("이름", "총점", "평균", sep="\t")
for student in students:
    # 점수의 총합과 평균을 구합니다.
    score_sum = student["korean"] + student["math"] +\
        student["english"] + student["science"]
    score_average = score_sum / 4
    # 출력합니다.
    print(student["name"], score_sum, score_average, sep="\t")
    
    
def  score_make_total(student):
    return  student["korean"] + student["math"] +\
        student["english"] + student["science"]

def  score_make_average(student):
    return score_make_total(student) / 4

def score_print_str(student):    
    return "{}\t{}\t{}".format(student["name"], score_make_total(student), \
          score_make_average(student)) 

# 학생을 한 명씩 반복합니다.
print("이름", "총점", "평균", sep="\t")
for student in students:
    # 출력합니다.
    print(score_print_str(student))

# %%
# 학생 리스트를을 선언합니다.
students = [
    { "name": "김지욘", "korean": 87, "math": 98, "english": 88, "science": 95 },
    { "name": "연하진", "korean": 92, "math": 98, "english": 96, "science": 98 },
    { "name": "구지연", "korean": 76, "math": 96, "english": 94, "science": 90 },
    { "name": "나선주", "korean": 98, "math": 92, "english": 96, "science": 92 },
    { "name": "윤아린", "korean": 95, "math": 98, "english": 98, "science": 98 },
    { "name": "윤명월", "korean": 64, "math": 88, "english": 92, "science": 92 },
    { "name": "김미화", "korean": 82, "math": 86, "english": 98, "science": 88 },
    { "name": "김연화", "korean": 88, "math": 74, "english": 78, "science": 92 },
    { "name": "박아현", "korean": 97, "math": 92, "english": 88, "science": 95 },
    { "name": "서준서", "korean": 45, "math": 52, "english": 72, "science": 78 }
]

def create_student(name,korean,math,english,science):
    return {
        "name":name,
        "korean":korean,
        "math":math,
        "english":english,
        "science":science,
        }

bb = create_student("aaa",90,80,70,60)
print(bb)

students1 = [
    create_student("aaa",90,80,70,60),
    create_student("bbb",90,50,70,80),
    create_student("ccc",90,90,70,40)    
    ]
print(students1)
    



# 학생을 한 명씩 반복합니다.
print("이름", "총점", "평균", sep="\t")
for student in students:
    # 점수의 총합과 평균을 구합니다.
    score_sum = student["korean"] + student["math"] +\
        student["english"] + student["science"]
    score_average = score_sum / 4
    # 출력합니다.
    print(student["name"], score_sum, score_average, sep="\t")
    
    
def  score_make_total(student):
    return  student["korean"] + student["math"] +\
        student["english"] + student["science"]

def  score_make_average(student):
    return score_make_total(student) / 4

def score_print_str(student):    
    return "{}\t{}\t{}".format(student["name"], score_make_total(student), \
          score_make_average(student)) 

# 학생을 한 명씩 반복합니다.
print("이름", "총점", "평균", sep="\t")
for student in students:
    # 출력합니다.
    print(score_print_str(student))
    
# 학생을 한 명씩 반복합니다.
print("이름", "총점", "평균", sep="\t")
for student in students1:
    # 출력합니다.
    print(score_print_str(student))
